# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from datetime import datetime

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 608

# %%
print(cities)
# Out:
# ['ponta do sol', 'rochegda', 'barrow', 'hermanus', 'bambous virieux', 'necochea', 'tsihombe', 'grand river south east', 'isangel', 'rikitea', 'kodiak', 'cavan', 'yellowknife', 'bani', 'butaritari', 'busselton', 'port elizabeth', 'severo-kurilsk', 'lubao', 'kasamwa', 'ushuaia', 'bulgan', 'atuona', 'kahului', 'arlit', 'arraial do cabo', 'gambela', 'carnarvon', 'santander', 'albany', 'beringovskiy', 'airai', 'ribeira grande', 'provideniya', 'kingman', 'college', 'new norfolk', 'barentsburg', 'sawakin', 'vaini', 'siniscola', 'kimbe', 'punta arenas', 'avarua', 'samalaeulu', 'east london', 'arroyo', 'hasaki', 'castro', 'belushya guba', 'tazovskiy', 'labuhan', 'nikolskoye', 'hobart', 'san cristobal', 'grindavik', 'mandalgovi', 'bengkulu', 'kokopo', 'riviere-au-renard', 'mount gambier', 'taolanaro', 'tiksi', 'khatanga', 'san patricio', 'kapaa', 'hvammstangi', 'metu', 'bluff', 'high level', 'chokurdakh', 'aykhal', 'hithadhoo', 'myitkyina', 'leningradskiy', 'qaanaaq', 'vicam', 'wanxian', 'cherskiy', 'jacmel', 'puerto ayora', 'dikson', 'amderma', 'merrill', 'viligili', 'puerto del rosario', 'marsh harbour', 'attawapiskat', 'bredasdorp', 'hamilton', 'progreso', 'esperance', 'aasiaat', 'northam', 'chuy', 'tabialan', 'touros', 'katsuura', 'kaitangata', 'faanui', 'muros', 'thompson', 'atkarsk', 'zhengjiatun', 'berlevag', 'inirida', 'sabha', 'cidreira', 'baykit', 'uthai thani', 'mataura', 'vanimo', 'meulaboh', 'anadyr', 'sorong', 'souillac', 'nyurba', 'yulara', 'valkeala', 'saldanha', 'vardo', 'troitskoye', 'kabanga', 'vao', 'luderitz', 'tiarei', 'ostersund', 'talnakh', 'glenwood springs', 'ambon', 'nanortalik', 'salinas', 'clyde river', 'nome', 'surt', 'byron bay', 'ahipara', 'sechura', 'cape town', 'palabuhanratu', 'saleaula', 'saint-philippe', 'port hardy', 'dunedin', 'allanridge', 'lingyuan', 'iqaluit', 'adrar', 'hilo', 'senmonorom', 'yakhroma', 'fray bentos', 'tasiilaq', 'pacific grove', 'phonhong', 'egvekinot', 'krasnoyarskiy', 'palmer', 'olean', 'oberuzwil', 'nizhneyansk', 'kamenskoye', 'leh', 'santiago del estero', 'lavrentiya', 'sindhnur', 'grand gaube', 'svetlyy', 'georgetown', 'seoul', 'taoudenni', 'virginia beach', 'tuktoyaktuk', 'sept-iles', 'mys shmidta', 'kushiro', 'port alfred', 'jamestown', 'tonota', 'malanje', 'jerusalem', 'haines junction', 'bandarbeyla', 'puerto leguizamo', 'carbonear', 'mar del plata', 'kemi', 'san ignacio de sabaneta', 'beckley', 'arrifes', 'harta', 'tuatapere', 'caravelas', 'putyatino', 'cayenne', 'ariquemes', 'cap malheureux', 'mildura', 'saskylakh', 'aklavik', 'guaraniacu', 'lagoa', 'ilulissat', 'vila', 'illoqqortoormiut', 'aflu', 'puerto escondido', 'mahebourg', 'bambanglipuro', 'teya', 'berovo', 'lasa', 'udayagiri', 'manavalakurichi', 'pechenga', 'thunder bay', 'umm kaddadah', 'chala', 'belluru', 'abalak', 'borogontsy', 'harbour breton', 'singapore', 'ixtapa', 'iznik', 'eyl', 'mnogovershinnyy', 'yaan', 'nola', 'itigi', 'tura', 'namibe', 'karkaralinsk', 'longyearbyen', 'kuche', 'kruisfontein', 'mahanoro', 'comapa', 'kisangani', 'alipur', 'traverse city', 'alice springs', 'cortez', 'stromness', 'camacha', 'bhan', 'alizai', 'port-cartier', 'preobrazheniye', 'cabo san lucas', 'oistins', 'avera', 'westport', 'parthenay', 'peleduy', 'norman wells', 'ziro', 'solnechnyy', 'darhan', 'kuito', 'te anau', 'sulangan', 'mangochi', 'sistranda', 'bilma', 'lethem', 'russellville', 'el higo', 'belmonte', 'charters towers', 'torbay', 'alofi', 'klaksvik', 'victoria', 'poum', 'killybegs', 'quelimane', 'yerbogachen', 'saint-pierre', 'moose factory', 'jinxi', 'kavaratti', 'christchurch', 'salalah', 'steinbach', 'safita', 'lata', 'miyang', 'los llanos de aridane', 'codrington', 'manggar', 'ngunguru', 'ancud', 'atar', 'lolua', 'hovd', 'gawler', 'husavik', 'vila franca do campo', 'tilichiki', 'bethel', 'keflavik', 'guerrero negro', 'port lincoln', 'port moresby', 'walvis bay', 'port macquarie', 'miri', 'itoman', 'divo', 'lompoc', 'saint simons', 'dong hoi', 'palu', 'karratha', 'kishapu', 'ulaangom', 'rodrigues alves', 'kalab ...

# %% [markdown]
# ## Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url =f"{url}&units={units}&appid={weather_api_key}&q="
print(query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&appid=a8408b6e1ea2314fd02eb179a23ae369&q=

# %%
#just for test to see the format 
response =requests.get(query_url).json()
pprint(response)
# Out:
# {'cod': '400', 'message': 'Nothing to geocode'}

# %%
#cities =['ketchikan', 'alekseyevskaya', 'fuxin']

# %%
time.sleep(1)
#setting up several lists to hold the weather info (based on teh HW CSV)
city_id =[]
city_name = []
cloudiness = []
country = []
date =[]
humidity =[]
Lat =[]
Lng =[]
max_temp = []
wind_speed = []
count= 0
set_count =1
record_count = 0

print(cities)
# Out:
# ['ponta do sol', 'rochegda', 'barrow', 'hermanus', 'bambous virieux', 'necochea', 'tsihombe', 'grand river south east', 'isangel', 'rikitea', 'kodiak', 'cavan', 'yellowknife', 'bani', 'butaritari', 'busselton', 'port elizabeth', 'severo-kurilsk', 'lubao', 'kasamwa', 'ushuaia', 'bulgan', 'atuona', 'kahului', 'arlit', 'arraial do cabo', 'gambela', 'carnarvon', 'santander', 'albany', 'beringovskiy', 'airai', 'ribeira grande', 'provideniya', 'kingman', 'college', 'new norfolk', 'barentsburg', 'sawakin', 'vaini', 'siniscola', 'kimbe', 'punta arenas', 'avarua', 'samalaeulu', 'east london', 'arroyo', 'hasaki', 'castro', 'belushya guba', 'tazovskiy', 'labuhan', 'nikolskoye', 'hobart', 'san cristobal', 'grindavik', 'mandalgovi', 'bengkulu', 'kokopo', 'riviere-au-renard', 'mount gambier', 'taolanaro
imane', 'yerbogachen', 'saint-pierre', 'moose factory', 'jinxi', 'kavaratti', 'christchurch', 'salalah', 'steinbach', 'safita', 'lata', 'miyang', 'los llanos de aridane', 'codrington', 'manggar', 'ngunguru', 'ancud', 'atar', 'lolua', 'hovd', 'gawler', 'husavik', 'vila franca do campo', 'tilichiki', 'bethel', 'keflavik', 'guerrero negro', 'port lincoln', 'port moresby', 'walvis bay', 'port macquarie', 'miri', 'itoman', 'divo', 'lompoc', 'saint simons', 'dong hoi', 'palu', 'karratha', 'kishapu', 'ulaangom', 'rodrigues alves', 'kalab ...

# %%
#Loop through cities, append them to the relevant lists and print out the outcome 
for city in cities[:50]:
    time.sleep(1)
    count= count + 1 
    
    
    try:
        
        response =requests.get(query_url + city).json()
        city_id.append(response["id"])
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        Lat.append(response["coord"]["lat"])
        Lng.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
 # start a new set every 50 cities       
        if count > 49:
            count =0
            set_count+= 1
                          
        
            
        else:                  
            print(f"processing Record {count} of set {set_count}| {city}")  
    except(KeyError, IndexError):
        print("City not found, skipping")
# Out:
# processing Record 1 of set 1| ponta do sol
# processing Record 2 of set 1| rochegda
# processing Record 3 of set 1| barrow
# processing Record 4 of set 1| hermanus
# processing Record 5 of set 1| bambous virieux
# processing Record 6 of set 1| necochea
# City not found, skipping
# City not found, skipping
# processing Record 9 of set 1| isangel
# processing Record 10 of set 1| rikitea
# processing Record 11 of set 1| kodiak
# processing Record 12 of set 1| cavan
# processing Record 13 of set 1| yellowknife
# processing Record 14 of set 1| bani
# processing Record 15 of set 1| butaritari
# processing Record 16 of set 1| busselton
# processing Record 17 of set 1| port elizabeth
# processing Record 18 of set 1| severo-kurilsk
# processing Record 19 of set 1| lubao
# processing Record 20 of set 1| kasamwa
# processing Record 21 of set 1| ushuaia
# processing Record 22 of set 1| bulgan
# processing Record 23 of set 1| atuona
# processing Record 24 of set 1| kahului
# processing Record 25 of set 1| arlit
# processing Record 26 of set 1| arraial do cabo
# processing Record 27 of set 1| gambela
# processing Record 28 of set 1| carnarvon
# processing Record 29 of set 1| santander
# processing Record 30 of set 1| albany
# processing Record 31 of set 1| beringovskiy
# processing Record 32 of set 1| airai
# processing Record 33 of set 1| ribeira grande
# processing Record 34 of set 1| provideniya
# processing Record 35 of set 1| kingman
# processing Record 36 of set 1| college
# processing Record 37 of set 1| new norfolk
# City not found, skipping
# processing Record 39 of set 1| sawakin
# processing Record 40 of set 1| vaini
# processing Record 41 of set 1| siniscola
# processing Record 42 of set 1| kimbe
# processing Record 43 of set 1| punta arenas
# processing Record 44 of set 1| avarua
# City not found, skipping
# processing Record 46 of set 1| east london
# processing Record 47 of set 1| arroyo
# processing Record 48 of set 1| hasaki
# processing Record 49 of set 1| castro
# City not found, skipping

# %%
#make a datafreame with the lists that are made
my_weather_data= pd.DataFrame({"City_ID": city_id , "City" : city_name, "Cloudiness" :cloudiness , "Country": country, "Date": date, "Humidity":humidity, "Lat": Lat, "Lng": Lng, "Max Temp":max_temp , "Wind Speed": wind_speed})
# 15        85  50.68  156.12     43.25        3.71
# 16        94  14.92  120.55     78.80        4.70
# 17        84  -2.85   32.43     65.62        2.24
# 18        62 -54.80  -68.30     51.80       12.75
# 19        74  48.81  103.53     27.63        4.09
# 20        75  -9.80 -139.03     78.94       21.45
# 21        52  20.89 -156.47     87.80        5.82
# 22        15  18.74    7.39     80.24        9.93
# 23        73 -22.97  -42.03     77.00        8.05
# 24        87   8.25   34.58     71.42        4.09
# 25        82 -24.87  113.63     68.00       19.46
# 26        67  43.46   -3.80     59.00       12.75
# 27        83  42.60  -73.97     50.00        1.99
# 28        91  63.05  179.32     31.66        2.93
# 29        98  -8.93  125.41     60.69        2.06
# 30        88  38.52  -28.70     69.80       18.34
# 31        74  64.38 -173.30     30.20        1.28
# 32        16  35.19 -114.05     53.01       29.97
# 33        92  64.86 -147.80     30.20        9.17
# 34        64 -42.78  147.06     51.01        2.30
# 35        76  19.11   37.33     82.18        3.51
# 36        88 -21.20 -175.20     73.40       10.29
# 37        82  40.57    9.69     57.20       13.87
# 38        85  -5.55  150.14     78.58        2.86
# 39        40 -53.15  -70.92     53.60       35.57
# 40        73 -21.21 -159.78     75.20       14.99
# 41        87 -33.02   27.91     65.97       21.03
# 42        87  41.61   -4.80     48.00       11.41
# 43        93  35.73  140.83     51.80        5.82
# 44        76 -24.79  -50.01     69.73        5.39

# %% [markdown]
# ## Convert Raw Data to DataFrame
# * Save as csv

# %%
my_weather_data.to_csv(output_data_file, index= False) #, index_label ="City_ID")

# %%
#corrected-data_path = 'weatherAPI_data.csv'
corrected_data_path = "../output_data/cities.csv"

corrected_data_df = pd.read_csv(corrected_data_path)
corrected_data_df
# Out:
#     City_ID                     City  Cloudiness Country        Date  \
# 0   2264557             Ponta do Sol          75      PT  1603744595
# 1    501847                 Rochegda          97      RU  1603744596
# 2   5880054                   Barrow          90      US  1603744597
# 3   3366880                 Hermanus          85      ZA  1603744598
# 4   1106677          Bambous Virieux          40      MU  1603744599
# 5   3430443                 Necochea           0      AR  1603744600
# 6   2136825                  Isangel          18      VU  1603744604
# 7   4030556                  Rikitea         100      PF  1603744605
# 8   5866583        Saint Paul Harbor          40      US  1603744606
# 9   2965535                    Cavan          41      IE  1603744607
# 10  6185377              Yellowknife          75      CA  1603744608
# 11  3512067                     Baní          75      DO  1603744609
# 12  2110227               Butaritari         100      KI  1603744610
# 13  2075265                Busselton          48      AU  1603744611
# 14   964420           Port Elizabeth          99      ZA  1603744612
# 15  2121385          Severo-Kuril'sk          96      RU  1603744613
# 16  1705441                    Lubao          75      PH  1603744614
# 17   158289                  Kasamwa          76      TZ  1603744615
# 18  3833367                  Ushuaia          40      AR  1603744616
# 19  2032201                   Bulgan           4      MN  1603744617
# 20  4020109                   Atuona          88      PF  1603744618
# 21  5847411                  Kahului          20      US  1603744620
# 22  2447513                    Arlit           0      NE  1603744621
# 23  3471451          Arraial do Cabo          40      BR  1603744622
# 24   337405                  Gambēla          39      ET  1603744623
# 25  2074865                Carnarvon           0      AU  1603744624
# 26  3109718                Santander          40      ES  1603744625
# 27  5106841                   Albany         100      US  1603744417
# 28  2126710             Beringovskiy           0      RU  1603744627
# 29  1651810                    Airai          83      TL  1603744628
# 30  3372707           Ribeira Grande          75      PT  1603744629
# 31  4031574              Provideniya          90      RU  1603744630
# 32  5301067                  Kingman           1      US  1603744354
# 33  5859699                  College          90      US  1603744559
# 34  2155415              New Norfolk         100      AU  1603744634
# 35   367544                  Sawākin          12      SD  1603744636
# 36  4032243                    Vaini          40      TO  1603744637
# 37  3166509                Siniscola          40      IT  1603744638
# 38  2093967                    Kimbe          85      PG  1603744639
# 39  3874787             Punta Arenas          20      CL  1603744492
# 40  4035715                   Avarua         100      CK  1603744641
# 41  1006984              East London         100      ZA  1603744643
# 42  3129371  Arroyo de la Encomienda           0      ES  1603744644
# 43  2112802                   Hasaki          75      JP  1603744646
# 44  3466704                   Castro          96      BR  1603744647
#
#     Humidity    Lat     Lng  Max Temp  Wind Speed
# 0         72  32.67  -17.10     66.20        8.05
# 1         97  62.80   43.25     28.35        9.24
# 2         85  71.29 -156.79     19.40        5.82
# 3         85 -34.42   19.23     63.00        4.00
# 4         73 -20.34   57.76     73.40       10.29
# 5         60 -38.55  -58.74     60.87        5.97
# 6         72 -19.55  169.27     77.20       13.73
# 7         84 -23.12 -134.97     75.36       18.95
# 8         46  57.79 -152.41     50.00       16.11
# 9         87  53.99   -7.36     45.00        3.00
# 10        62  62.46 -114.35     24.80        5.82
# 11        79  18.28  -70.33     87.01       12.64
# 12        66   3.07  172.79     81.55        7.81
# 13        77 -33.65  115.33     57.00        9.33
# 14        88 -33.92   25.57     64.40       19.46
# 15        85  50.68  156.12     43.25        3.71
# 16        94  14.92  120.55     78.80        4.70
# 17        84  -2.85   32.43     65.62        2.24
# 18        62 -54.80  -68.30     51.80       12.75
# 19        74  48.81  103.53     27.63        4.09
# 20        75  -9.80 -139.03     78.94       21.45
# 21        52  20.89 -156.47     87.80        5.82
# 22        15  18.74    7.39     80.24        9.93
# 23        73 -22.97  -42.03     77.00        8.05
# 24        87   8.25   34.58     71.42        4.09
# 25        82 -24.87  113.63     68.00       19.46
# 26        67  43.46   -3.80     59.00       12.75
# 27        83  42.60  -73.97     50.00        1.99
# 28        91  63.05  179.32     31.66        2.93
# 29        98  -8.93  125.41     60.69        2.06
# 30        88  38.52  -28.70     69.80       18.34
# 31        74  64.38 -173.30     30.20        1.28
# 32        16  35.19 -114.05     53.01       29.97
# 33        92  64.86 -147.80     30.20        9.17
# 34        64 -42.78  147.06     51.01        2.30
# 35        76  19.11   37.33     82.18        3.51
# 36        88 -21.20 -175.20     73.40       10.29
# 37        82  40.57    9.69     57.20       13.87
# 38        85  -5.55  150.14     78.58        2.86
# 39        40 -53.15  -70.92     53.60       35.57
# 40        73 -21.21 -159.78     75.20       14.99
# 41        87 -33.02   27.91     65.97       21.03
# 42        87  41.61   -4.80     48.00       11.41
# 43        93  35.73  140.83     51.80        5.82
# 44        76 -24.79  -50.01     69.73        5.39

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ### Latitude vs. Temperature Plot

# %%
date = time.strftime("%m/%d/%y") 
lat_data = corrected_data_df["Lat"]
temp_data = corrected_data_df["Max Temp"]
plt.scatter(lat_data, temp_data, marker ="o", edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.grid(True)
plt.title(f"City Latitude vs Max Temperature {date}")
plt.savefig("Images/Lat_vs_temp.png")
plt.show()

# %% [markdown]
# ### Latitude vs. Humidity Plot

# %%
hume_data = corrected_data_df["Humidity"]
plt.scatter(lat_data, hume_data, marker ="o", edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid(True)
plt.title(f"City Latitude vs Humidity {date}")
plt.savefig("Images/Lat_vs_hume.png")
plt.show()

# %% [markdown]
# ### Latitude vs. Cloudiness Plot

# %%
cloud_data = corrected_data_df["Cloudiness"]
plt.scatter(lat_data, cloud_data, marker ="o", edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid(True)
plt.title(f"City Latitude vs Cloudiness {date}")
plt.savefig("Images/Lat_vs_cloud.png")
plt.show()

# %% [markdown]
# ### Latitude vs. Wind Speed Plot

# %%
hume_data = corrected_data_df["Wind Speed"]
plt.scatter(lat_data, hume_data, marker ="o", edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid(True)
plt.title(f"City Latitude vs Wind Speed {date}")
plt.savefig("Images/Lat_vs_Wind_Speed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ### Write linear regression plot function (optional)

# %%
def linear_regression(x,y,y_label,coordinates):
    
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x,y)
    plt.plot(x,regress_values,"r-")
    plt.annotate(line_eq,coordinates,fontsize=15,color="red")
    print(f"the r-value is : {rvalue**2}")
    plt.xlabel('Latitutde')
    plt.ylabel(y_label)
    plt.show()

# %% [markdown]
# ###  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#make a regin with lat (0,80)
#Correlating the 
nh_mt = corrected_data_df[corrected_data_df["Lat"] >=0]
nh_mt

    
x= nh_mt["Lat"]
y= nh_mt["Max Temp"]
linear_regression(x,y,"Max Temp",(10,50))
# Out:
# the r-value is : 0.8470878237426251

# %% [markdown]
# ###  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
sh_mt = corrected_data_df[corrected_data_df["Lat"] < 0]
sh_mt

x= sh_mt["Lat"]
y= sh_mt["Max Temp"]
linear_regression(x,y,"Max Temp",(-50,70))
# Out:
# the r-value is : 0.5317859010200324

# %% [markdown]
# ###  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x= nh_mt["Lat"]
y= nh_mt["Humidity"]
linear_regression(x,y,"Humidity",(10,50))
# Out:
# the r-value is : 0.052686139384388195

# %% [markdown]
# ###  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x= sh_mt["Lat"]
y= sh_mt["Humidity"]
linear_regression(x,y,"Humidity",(-50,70))
# Out:
# the r-value is : 0.42351495920955345

# %% [markdown]
# ###  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x= nh_mt["Lat"]
y= nh_mt["Cloudiness"]
linear_regression(x,y,"Coudiness",(40,20))
# Out:
# the r-value is : 0.032197914869476756

# %% [markdown]
# ###  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x= sh_mt["Lat"]
y= sh_mt["Cloudiness"]
linear_regression(x,y,"Coudiness",(-40,20))
# Out:
# the r-value is : 0.06819667533445925

# %% [markdown]
# ###  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x= nh_mt["Lat"]
y= nh_mt["Wind Speed"]
linear_regression(x,y,"Wind Speed",(40,20))
# Out:
# the r-value is : 0.006761744797516957

# %% [markdown]
# ###  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x= sh_mt["Lat"]
y= sh_mt["Wind Speed"]
linear_regression(x,y,"Wind Speed",(-40,20))
# Out:
# the r-value is : 0.13517512725641162
